# %% [markdown]
# # Deepfake Audio Detection - Dataset Exploration
#
# ## Objective
#
# The goal of this project is to classify an audio recording as:
#
# - Human Speech
# - AI Generated (Deepfake) Speech
#
# This notebook will be used to:
#
# 1. Explore the dataset
# 2. Analyze audio files
# 3. Understand feature extraction
# 4. Prepare data for model training

# %%
print("Deepfake Audio Detection Project Started")
# Out:
# Deepfake Audio Detection Project Started
